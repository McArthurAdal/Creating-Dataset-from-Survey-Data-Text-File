# %% [markdown]
# # Create Presurvey Data

# %%
import numpy as np
import pandas as pd
import re

# %%
def get_text(path):
    with open(path) as file:
        text = np.loadtxt(file, delimiter='\n',dtype='str')

    return pd.DataFrame(text)

# %%
presurvey_path = 'presurveytext.txt'
data = get_text(presurvey_path)

# %%
def add_and_modify_columns(df):
    columns_to_add = ['strongly agree','agree','neither agree','disagree','strongly disagree']
    df[columns_to_add] = 0
    mapper = {0:'question'}
    df.rename(mapper,inplace=True,axis=1)
    return df

# %%
data = add_and_modify_columns(data)

# %%
def extract_percentages(df):
    full_list = []
    for index in range(1,20):
        if index%2 != 0:
            row = df.iloc[index,0]
            row = re.findall('[0-9] | [0-9][0-9]',str(row))
            values = [float(x) for x in row]
            full_list.append(values)
    return full_list

# %%
percentages = extract_percentages(data)

# %%
def reset_indices(df):
    indexes = []
    for index in range(1,20):
        if index%2 != 0:
            indexes.append(index)

    df.drop(indexes,axis=0,inplace=True)
    df.reset_index(drop=True,inplace=True)
    return df

# %%
data = reset_indices(data)

# %%
def insert_values_into(df, p):
    data_x = pd.DataFrame(p,columns=df.columns[1:])
    return data_x

data_n = insert_values_into(data,percentages)
data_n
# Out:
#    strongly agree  agree  neither agree  disagree  strongly disagree
# 0             0.0   10.0           40.0      40.0               10.0
# 1             0.0    0.0           20.0      30.0               50.0
# 2             0.0   20.0           30.0      30.0               20.0
# 3             0.0    0.0           20.0      50.0               30.0
# 4             0.0    0.0           30.0      20.0               50.0
# 5             0.0   20.0           20.0      40.0               20.0
# 6             0.0   20.0            0.0      70.0               10.0
# 7             0.0    0.0            0.0      80.0               20.0
# 8             0.0   20.0           30.0      50.0                0.0
# 9             0.0    0.0           30.0      30.0               30.0

# %%
def add_questions_and_reorder_columns(df):
    df['question'] = data['question']
    #mapper = {0:'question'}
    #data_n.rename(mapper,inplace=True,axis=1)
    cols = ['question','strongly agree','agree','neither agree','disagree','strongly disagree']
    df= df[cols]
    return df

# %%
data_n = add_questions_and_reorder_columns(data_n)
data_n
# Out:
#                                             question  strongly agree  agree  \
# 0  I feel comftable discussing my background, bel...             0.0   10.0
# 1  Perspectives like mine are included in decisio...             0.0    0.0
# 2  The people I wk with are respectful to one ano...             0.0   20.0
# 3  This ganization provides a safe environment f ...             0.0    0.0
# 4  I can voice a contrary opinion without fear of...             0.0    0.0
# 5  I feel I can achieve success as my authentic s...             0.0   20.0
# 6  I can attend to an urgent personal matter duri...             0.0   20.0
# 7  This ganization encourages a good balance betw...             0.0    0.0
# 8           I feel like I belong at this ganization.             0.0   20.0
# 9  The ganization has a diverse management team. ...             0.0    0.0
#
#    neither agree  disagree  strongly disagree
# 0           40.0      40.0               10.0
# 1           20.0      30.0               50.0
# 2           30.0      30.0               20.0
# 3           20.0      50.0               30.0
# 4           30.0      20.0               50.0
# 5           20.0      40.0               20.0
# 6            0.0      70.0               10.0
# 7            0.0      80.0               20.0
# 8           30.0      50.0                0.0
# 9           30.0      30.0               30.0

# %%
data_n.to_csv('presurvey_wout_tr_pipe.csv')

# %% [markdown]
# # Create Postsurvey Dataset

# %%
postsurvey_path = 'postsurveytext.txt'
data_post = get_text(postsurvey_path)

# %%
data_post
# Out:
#                                                     0
# 0   1. I feel comftable cussig my backgroud, belie...
# 1                              0   30  40     30  0
# 2   2. Perspectives like mie are icluded i decisio...
# 3                            10   30  20     30  10
# 4   3. The people I wk with are respectful to oe a...
# 5                               0   60  0     40  0
# 6   4. This gaizatio provides a safe eviromet f th...
# 7                              0   20  60     20  0
# 8   5. I ca voice a cotrary opiio without fear of ...
# 9                              0   0  50     30  20
# 10  6. I feel I ca achieve success as my authetic ...
# 11                            0   30  50     10  10
# 12  7. I ca atted to a urget persoal matter durig ...
# 13                            0   60  10     20  10
# 14  8. This gaizatio ecourages a good balace betwe...
# 15                            0   10  50     30  10
# 16           9. I feel like I belog at this gaizatio.
# 17                             0   50  40     10  0
# 18  10. The gaizatio has a diverse maagemet team. ...
# 19                             0   0  50     20  30

# %%
data_post = add_and_modify_columns(data_post)

# %%
percent = extract_percentages(data_post)
percent
# Out:
# [[0.0, 30.0, 40.0, 30.0, 0.0],
#  [0.0, 30.0, 20.0, 30.0, 10.0],
#  [0.0, 60.0, 0.0, 40.0, 0.0],
#  [0.0, 20.0, 60.0, 20.0, 0.0],
#  [0.0, 0.0, 50.0, 30.0, 20.0],
#  [0.0, 30.0, 50.0, 10.0, 10.0],
#  [0.0, 60.0, 10.0, 20.0, 10.0],
#  [0.0, 10.0, 50.0, 30.0, 10.0],
#  [0.0, 50.0, 40.0, 10.0, 0.0],
#  [0.0, 0.0, 50.0, 20.0, 30.0]]

# %%
data_post = reset_indices(data_post)
data_post
# Out:
#                                             question  strongly agree  agree  \
# 0  1. I feel comftable cussig my backgroud, belie...               0      0
# 1  2. Perspectives like mie are icluded i decisio...               0      0
# 2  3. The people I wk with are respectful to oe a...               0      0
# 3  4. This gaizatio provides a safe eviromet f th...               0      0
# 4  5. I ca voice a cotrary opiio without fear of ...               0      0
# 5  6. I feel I ca achieve success as my authetic ...               0      0
# 6  7. I ca atted to a urget persoal matter durig ...               0      0
# 7  8. This gaizatio ecourages a good balace betwe...               0      0
# 8           9. I feel like I belog at this gaizatio.               0      0
# 9  10. The gaizatio has a diverse maagemet team. ...               0      0
#
#    neither agree  disagree  strongly disagree
# 0              0         0                  0
# 1              0         0                  0
# 2              0         0                  0
# 3              0         0                  0
# 4              0         0                  0
# 5              0         0                  0
# 6              0         0                  0
# 7              0         0                  0
# 8              0         0                  0
# 9              0         0                  0

# %%
data_post = insert_values_into(data_post,percent)
data_post
# Out:
#    strongly agree  agree  neither agree  disagree  strongly disagree
# 0             0.0   30.0           40.0      30.0                0.0
# 1             0.0   30.0           20.0      30.0               10.0
# 2             0.0   60.0            0.0      40.0                0.0
# 3             0.0   20.0           60.0      20.0                0.0
# 4             0.0    0.0           50.0      30.0               20.0
# 5             0.0   30.0           50.0      10.0               10.0
# 6             0.0   60.0           10.0      20.0               10.0
# 7             0.0   10.0           50.0      30.0               10.0
# 8             0.0   50.0           40.0      10.0                0.0
# 9             0.0    0.0           50.0      20.0               30.0

# %%
data_post = add_questions_and_reorder_columns(data_post)
data_post.to_csv('postsurvey_wout_tr_pipe.csv')
data_post
# Out:
#                                             question  strongly agree  agree  \
# 0  I feel comftable discussing my background, bel...             0.0   30.0
# 1  Perspectives like mine are included in decisio...             0.0   30.0
# 2  The people I wk with are respectful to one ano...             0.0   60.0
# 3  This ganization provides a safe environment f ...             0.0   20.0
# 4  I can voice a contrary opinion without fear of...             0.0    0.0
# 5  I feel I can achieve success as my authentic s...             0.0   30.0
# 6  I can attend to an urgent personal matter duri...             0.0   60.0
# 7  This ganization encourages a good balance betw...             0.0   10.0
# 8           I feel like I belong at this ganization.             0.0   50.0
# 9  The ganization has a diverse management team. ...             0.0    0.0
#
#    neither agree  disagree  strongly disagree
# 0           40.0      30.0                0.0
# 1           20.0      30.0               10.0
# 2            0.0      40.0                0.0
# 3           60.0      20.0                0.0
# 4           50.0      30.0               20.0
# 5           50.0      10.0               10.0
# 6           10.0      20.0               10.0
# 7           50.0      30.0               10.0
# 8           40.0      10.0                0.0
# 9           50.0      20.0               30.0
